# %% [markdown]
# # FastAPI Application Profiling with SnakeViz
#
# This notebook demonstrates how to visualize the profiling results of a FastAPI application using SnakeViz.

# %%
import cProfile
import pstats

# %% [markdown]
# ## Visualize Profiling Results
#
# Replace `'profiling_results.prof'` with the path to your actual `.prof` file.

# %%
# Make sure to replace 'profiling_results.prof' with the path to your actual .prof file
profiling_file = 'profiling_results/profiling_results.prof'

# %load_ext snakeviz
# !snakeviz -s {profiling_file}
